# %% [markdown]
# <a href="https://colab.research.google.com/github/srimathi2025/Environmental-Water-quality-DrKK/blob/main/Exam_10_9_2026_4_28_pm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
tesla=yf.Ticker("TSLA")
tesla_data=tesla.history(period="max")
tesla_data.info()
tesla_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4032 entries, 2010-06-29 00:00:00-04:00 to 2026-07-10 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          4032 non-null   float64
#  1   High          4032 non-null   float64
#  2   Low           4032 non-null   float64
#  3   Close         4032 non-null   float64
#  4   Volume        4032 non-null   int64
#  5   Dividends     4032 non-null   float64
#  6   Stock Splits  4032 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 252.0 KB
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# ...

# %%
# Load GameStop (GME) stock data
gme = yf.Ticker("GME")
gme_data = gme.history(period="max")
gme_data.info()
gme_data.head(5)
